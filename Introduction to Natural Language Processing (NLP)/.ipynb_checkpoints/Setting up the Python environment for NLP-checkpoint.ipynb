# %% [markdown]
# ## Installing Dependencies
# These are the modules I am installing at the start of this course
# We will use these modules for NLP tasks so lets install them

# %%
# !pip install nltk spacy textblob

# %% [markdown]
# Install the english model for SpaCy

# %% [markdown]
# ## Step 3: Verify the installations

# %% [markdown]
# Use the below code to check if these are installed properly in your system

# %%
# Verify the installation
import nltk, spacy, textblob
print("All dependencies are installed correctly!")
nlp = spacy.load('en_core_web_sm')
print("Spacy model loaded successfully")
# Out:
# All dependencies are installed correctly!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Verify the installation
#       2 import nltk, spacy, textblob
#       3 print("All dependencies are installed correctly!")
# ----> 4 nlp = spacy.load('en_core_web_sm')
#       5 print("Spacy model loaded successfully")
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\spacy\__init__.py:74, in load(name, vocab, disable, enable, exclude, config)
#      50 def load(
#      51     name: Union[str, Path],
#      52     *,
#    (...)     57     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      58 ) -> Language:
#      59     """Load a spaCy model from an installed package or a local path.
#      60
#      61     name (str): Package name or model path.
#    (...)     72     RETURNS (Language): The loaded nlp object.
#      73     """
# ---> 74     return util.load_model(
#      75         name,
#      76         vocab=vocab,
#      77         disable=disable,
#      78         enable=enable,
#      79         exclude=exclude,
#      80         config=config,
#      81     )
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\spacy\util.py:531, in load_model(name, vocab, disable, enable, exclude, config)
#     529 if name in OLD_MODEL_SHORTCUTS:
#     530     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 531 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %% [markdown]
# ## Step 4: Download NLTK Data

# %% [markdown]
# NLTK requires some additional datasets. Use the code below to download them.

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# %% [markdown]
# ## Step - 6: Test Your Setup

# %% [markdown]
# You can run the following code to test your setup

# %%
# Test your code with tokenization
from nltk.tokenize import word_tokenize
text = 'Hello, NLP World'
tokens = word_tokenize(text)
print("Tokens: ", tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Test your code with tokenization
#       2 from nltk.tokenize import word_tokenize
#       3 text = 'Hello, NLP World'
# ----> 4 tokens = word_tokenize(text)
#       5 print("Tokens: ", tokens)
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)    140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
#     144         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     145     ]
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\tokenize\__init__.py:119, in sent_tokenize(text, language)
#     109 def sent_tokenize(text, language="english"):
#     110     """
#     111     Return a sentence-tokenized copy of *text*,
#     112     using NLTK's recommended sentence tokenizer
#    (...)    117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\tokenize\__init__.py:105, in _get_punkt_tokenizer(language)
#      96 @functools.lru_cache
#      97 def _get_punkt_tokenizer(language="english"):
#      98     """
#      99     A constructor for the PunktTokenizer that utilizes
#     100     a lru cache for performance.
#    (...)    103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\tokenize\punkt.py:1764, in PunktTokenizer.__init__(self, lang)
#    1762 def __init__(self, lang="english"):
#    1763     PunktSentenceTokenizer.__init__(self)
# -> 1764     self.load_lang(lang)
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\tokenize\punkt.py:1769, in PunktTokenizer.load_lang(self, lang)
#    1766 def load_lang(self, lang="english"):
#    1767     from nltk.data import find
# -> 1769     lang_dir = find(f"tokenizers/punkt_tab/{lang}/")
#    1770     self._params = load_punkt_params(lang_dir)
#    1771     self._lang = lang
#
# File D:\Me\Machine Learning\NLP\Classes\nlp_env\Lib\site-packages\nltk\data.py:877, in find(resource_name, paths)
#     875 sep = "*" * 70
#     876 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 877 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'punkt_tab' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt_tab')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'tokenizers/punkt_tab/english/'
#
#   Searched in:
#     - 'C:\\Users\\DELL/nltk_data'
#     - 'D:\\Me\\Machine Learning\\NLP\\Classes\\nlp_env\\nltk_data'
#     - 'D:\\Me\\Machine Learning\\NLP\\Classes\\nlp_env\\share\\nltk_data'
#     - 'D:\\Me\\Machine Learning\\NLP\\Classes\\nlp_env\\lib\\nltk_data'
#     - 'C:\\Users\\DELL\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

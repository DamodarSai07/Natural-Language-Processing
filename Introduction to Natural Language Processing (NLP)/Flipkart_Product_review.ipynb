# %%
import numpy as np
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import os

nltk.download('punkt') #Ensure punkt is available
nltk.download('stopwords') #Ensure stopwords are available
nltk.download('wordnet') #Ensure wordnet is available
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
reveiws = pd.read_csv('../Datasets/Dataset-SA.csv')
reveiws.head()
# Out:
#                                         product_name product_price Rate  \
# 0  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 1  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    5
# 2  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
# 3  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    1
# 4  Candes 12 L Room/Personal Air Cooler??????(Whi...          3999    3
#
#             Review                                            Summary  \
# 0           super!  great cooler excellent air flow and for this p...
# 1          awesome              best budget 2 fit cooler nice cooling
# 2             fair  the quality is good but the power of air is de...
# 3  useless product                  very bad product its a only a fan
# 4             fair                                      ok ok product
#
#   Sentiment
# 0  positive
# 1  positive
# 2  positive
# 3  negative
# 4   neutral

# %%
print(reveiws['Summary'])
# Out:
# 0         great cooler excellent air flow and for this p...
# 1                     best budget 2 fit cooler nice cooling
# 2         the quality is good but the power of air is de...
# 3                         very bad product its a only a fan
# 4                                             ok ok product
#                                 ...
# 205047                                         good product
# 205048                                                 nice
# 205049                          very nice and fast delivery
# 205050                                      awesome product
# 205051    very good but mixing bowl not included is one ...
# Name: Summary, Length: 205052, dtype: str

# %%
review = reveiws.Summary[0]
tokens = word_tokenize(review)
print("Tokens: ", tokens)
# Out:
# Tokens:  ['great', 'cooler', 'excellent', 'air', 'flow', 'and', 'for', 'this', 'price', 'its', 'so', 'amazing', 'and', 'unbelievablejust', 'love', 'it']

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("Filtered Tokens: ", filtered_tokens)
# Out:
# Filtered Tokens:  ['great', 'cooler', 'excellent', 'air', 'flow', 'price', 'amazing', 'unbelievablejust', 'love']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stemmer = PorterStemmer()
stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
print("Stemmed Tokens: ", stemmed_tokens)
# Out:
# Stemmed Tokens:  ['great', 'cooler', 'excel', 'air', 'flow', 'price', 'amaz', 'unbelievablejust', 'love']

# %%
nltk.download('wordnet')
from nltk.corpus import wordnet
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
print("Lemmatized Tokens: ", lemmatized_tokens)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Lemmatized Tokens:  ['great', 'cooler', 'excellent', 'air', 'flow', 'price', 'amazing', 'unbelievablejust', 'love']

# %%
text = "Great Mobile. Good Camera, Good Battery, Good Processor, Good Display. Just loving it. One of the best phones ever released by OnePlus"
text_tokens = word_tokenize(text)
print(text_tokens)
print(len(text_tokens))
# Out:
# ['Great', 'Mobile', '.', 'Good', 'Camera', ',', 'Good', 'Battery', ',', 'Good', 'Processor', ',', 'Good', 'Display', '.', 'Just', 'loving', 'it', '.', 'One', 'of', 'the', 'best', 'phones', 'ever', 'released', 'by', 'OnePlus']
# 28

# %%
from nltk.corpus import stopwords
filtered_text_tokens = [token for token in text_tokens if token.lower() not in stop_words]
print("Filtered Text Tokens",filtered_text_tokens)
print(len(filtered_text_tokens))
# Out:
# Filtered Text Tokens ['Great', 'Mobile', '.', 'Good', 'Camera', ',', 'Good', 'Battery', ',', 'Good', 'Processor', ',', 'Good', 'Display', '.', 'loving', '.', 'One', 'best', 'phones', 'ever', 'released', 'OnePlus']
# 23

# %%
stemmed_tokens = [stemmer.stem(word) for word in filtered_text_tokens]
print("Stemmed Tokens: ", stemmed_tokens)
# Out:
# Stemmed Tokens:  ['great', 'mobil', '.', 'good', 'camera', ',', 'good', 'batteri', ',', 'good', 'processor', ',', 'good', 'display', '.', 'love', '.', 'one', 'best', 'phone', 'ever', 'releas', 'oneplu']

# %%
lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_text_tokens]
print("Lemmatized Tokens: ", lemmatized_tokens)
# Out:
# Lemmatized Tokens:  ['Great', 'Mobile', '.', 'Good', 'Camera', ',', 'Good', 'Battery', ',', 'Good', 'Processor', ',', 'Good', 'Display', '.', 'loving', '.', 'One', 'best', 'phone', 'ever', 'released', 'OnePlus']

# %%
review['Summary']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 review['Summary']
#
# TypeError: string indices must be integers, not 'str'

# %%
word = reviews['Summary'][1]
word
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 word = reviews['Summary'][1]
#       2 word
#
# NameError: name 'reviews' is not defined

# %%
type(review)
# Out:
# str

# %%
print(review)
# Out:
# great cooler excellent air flow and for this price its so amazing and unbelievablejust love it

# %%
type(reveiws)
# Out:
# pandas.DataFrame

# %%
reveiw_1 = reveiws.Summary[1]
reveiw_1
# Out:
# 'best budget 2 fit cooler nice cooling'

# %%
review_tokens = word_tokenize(reveiw_1)
print(review_tokens)
# Out:
# ['best', 'budget', '2', 'fit', 'cooler', 'nice', 'cooling']

# %%
stem_tokens = [stemmer.stem(word) for word in review_tokens if word not in stop_words]
print("Stemmed Tokens", stem_tokens)
# Out:
# Stemmed Tokens ['best', 'budget', '2', 'fit', 'cooler', 'nice', 'cool']

# %%
lem_tokens = [lemmatizer.lemmatize(word) for word in review_tokens if word not in stop_words]

# %%
print("Lemmatized Tokens", lem_tokens)
# Out:
# Lemmatized Tokens ['best', 'budget', '2', 'fit', 'cooler', 'nice', 'cooling']

# %%
reveiw_2 = reveiws.Summary[2]
reveiw_2
# Out:
# 'the quality is good but the power of air is decent'

# %%
r2_tokens = word_tokenize(reveiw_2)
print(r2_tokens)
# Out:
# ['the', 'quality', 'is', 'good', 'but', 'the', 'power', 'of', 'air', 'is', 'decent']

# %%
r2_stem = [stemmer.stem(word) for word in r2_tokens if word not in stop_words]
print(r2_stem)
# Out:
# ['qualiti', 'good', 'power', 'air', 'decent']

# %%
r2_lem = [lemmatizer.lemmatize(word) for word in r2_tokens if word not in stop_words]
print("Lemmatized Tokens", r2_lem)
# Out:
# Lemmatized Tokens ['quality', 'good', 'power', 'air', 'decent']

# %%
r3 = reveiws.Summary[3]
r3
# Out:
# 'very bad product its a only a fan'

# %%
r3_tokens = word_tokenize(r3)
print(r3_tokens)
# Out:
# ['very', 'bad', 'product', 'its', 'a', 'only', 'a', 'fan']

# %%
r3_stem = [stemmer.stem(word) for word in r3_tokens if word not in stop_words]
print("Stemmed Tokens", r3_stem)
# Out:
# Stemmed Tokens ['bad', 'product', 'fan']

# %%
r3_lem = [lemmatizer.lemmatize(word) for word in r3_tokens if word not in stop_words]
print("Lemmatized Tokens", r3_lem)
# Out:
# Lemmatized Tokens ['bad', 'product', 'fan']

# %%
r4 = reveiws.Summary[4]
r4
# Out:
# 'ok ok product'

# %%
r4_tokens = word_tokenize(r4)
print(r4_tokens)
# Out:
# ['ok', 'ok', 'product']

# %%
r4_stem = [stemmer.stem(word) for word in r4_tokens if word not in stop_words]
print("Stemmed Tokens", r4_stem)
# Out:
# Stemmed Tokens ['ok', 'ok', 'product']

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
r4_lem = [lemmatizer.lemmatize(word) for word in r4_tokens if word not in stop_words]
print("Lemmatized Tokens:", r4_lem)
# Out:
# Lemmatized Tokens: ['ok', 'ok', 'product']

# %%
r5 = reveiws.Summary[5]
r5
# Out:
# 'the cooler is really fantastic and provides good air flow highly recommended'

# %%
r5_tokens = word_tokenize(r5)
print(r5_tokens)
# Out:
# ['the', 'cooler', 'is', 'really', 'fantastic', 'and', 'provides', 'good', 'air', 'flow', 'highly', 'recommended']

# %%
r5_stem = [stemmer.stem(word) for word in r5_tokens if word not in stop_words]
print(r5_stem)
# Out:
# ['cooler', 'realli', 'fantast', 'provid', 'good', 'air', 'flow', 'highli', 'recommend']

# %%
r5_lem = [lemmatizer.lemmatize(word) for word in r5_tokens if word not in stop_words]
print(r5_lem)
# Out:
# ['cooler', 'really', 'fantastic', 'provides', 'good', 'air', 'flow', 'highly', 'recommended']

# %%
r1 = reveiws.Summary[6]
r1
# Out:
# 'very good product'

# %%
r1_tokens = word_tokenize(r1)
print("R1 Tokens: ", r1_tokens)
# Out:
# R1 Tokens:  ['very', 'good', 'product']

# %%
from nltk.corpus import stopwords
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
r1_stems = [stemmer.stem(word) for word in r1_tokens if word not in stop_words]
print("R1 after stemming: ", r1_stems)
# Out:
# R1 after stemming:  ['good', 'product']

# %%
lem = WordNetLemmatizer()
r1_lemmet = [lem.lemmatize(word) for word in r1_tokens if word not in stop_words]
print("R1 after lemmetization", r1_lemmet)
# Out:
# R1 after lemmetization ['good', 'product']

# %%
r7 = reveiws.Summary[7]
print(r7)
# Out:
# very nice

# %%
r7_tokens = word_tokenize(r7)
print("Tokenized R7: ", r7_tokens)
# Out:
# Tokenized R7:  ['very', 'nice']

# %%
r7_stems = [stemmer.stem(word) for word in r7_tokens if word not in stop_words]
print("R7 after stemming: ", r7_stems)
# Out:
# R7 after stemming:  ['nice']

# %%
r7_lems = [lem.lemmatize(word) for word in r7_tokens if word not in stop_words]
print("R7 after lemmetization: ", r7_lems)
# Out:
# R7 after lemmetization:  ['nice']

# %%
review_final = reveiws.Summary[256]
print(review_final)
# Out:
# nice cooler awesome product

# %%
final_tokens = word_tokenize(review_final)
print("Final Review Tokens: ", final_tokens)
# Out:
# Final Review Tokens:  ['nice', 'cooler', 'awesome', 'product']

# %%
final_lemmetize = [lem.lemmatize(word) for word in final_tokens if word not in stop_words]
print("Final Review after lemmetization: ", final_lemmetize)
# Out:
# Final Review after lemmetization:  ['nice', 'cooler', 'awesome', 'product']

# %%
final_stems = [stemmer.stem(word) for word in final_tokens if word not in stop_words]
print("Final Review after stemming: ", final_stems)
# Out:
# Final Review after stemming:  ['nice', 'cooler', 'awesom', 'product']

# %%
final_sentence = "Once upon a time there lived a ghost is no more a secret"
sent_tokens = word_tokenize(final_sentence)
sent_lem = [lem.lemmatize(word) for word in sent_tokens if word not in stop_words]
sent_stem = [stemmer.stem(word) for word in sent_tokens if word not in stop_words]
print("Final Sentence Tokens: ", sent_tokens)
print("Final Sentence after Stemming: ", sent_stem)
print("Final Sentence after Lemmetization: ", sent_lem)
# Out:
# Final Sentence Tokens:  ['Once', 'upon', 'a', 'time', 'there', 'lived', 'a', 'ghost', 'is', 'no', 'more', 'a', 'secret']
# Final Sentence after Stemming:  ['onc', 'upon', 'time', 'live', 'ghost', 'secret']
# Final Sentence after Lemmetization:  ['Once', 'upon', 'time', 'lived', 'ghost', 'secret']

# %%
testing_sentence = "Hello all my name is Dosa Damodar I am from Palakollu. My father name is Varaha Narasimha Swamy. My Mother Name is Venkata Maha Lakshmi. My Sister name is Vani Lakshmi Padmaja"
testing_tokens = word_tokenize(testing_sentence)
testing_stemming = [stemmer.stem(word) for word in testing_tokens if word not in stop_words]
testing_lemmatized = [lem.lemmatize(word) for word in testing_tokens if word not in stop_words]
print("Testing Sentence Tokens: ", testing_tokens)
print("Testing Sentence Stemmed: ", testing_stemming)
print("Testing Sentence Lemmetized: ", testing_lemmatized)
# Out:
# Testing Sentence Tokens:  ['Hello', 'all', 'my', 'name', 'is', 'Dosa', 'Damodar', 'I', 'am', 'from', 'Palakollu', '.', 'My', 'father', 'name', 'is', 'Varaha', 'Narasimha', 'Swamy', '.', 'My', 'Mother', 'Name', 'is', 'Venkata', 'Maha', 'Lakshmi', '.', 'My', 'Sister', 'name', 'is', 'Vani', 'Lakshmi', 'Padmaja']
# Testing Sentence Stemmed:  ['hello', 'name', 'dosa', 'damodar', 'i', 'palakollu', '.', 'my', 'father', 'name', 'varaha', 'narasimha', 'swami', '.', 'my', 'mother', 'name', 'venkata', 'maha', 'lakshmi', '.', 'my', 'sister', 'name', 'vani', 'lakshmi', 'padmaja']
# Testing Sentence Lemmetized:  ['Hello', 'name', 'Dosa', 'Damodar', 'I', 'Palakollu', '.', 'My', 'father', 'name', 'Varaha', 'Narasimha', 'Swamy', '.', 'My', 'Mother', 'Name', 'Venkata', 'Maha', 'Lakshmi', '.', 'My', 'Sister', 'name', 'Vani', 'Lakshmi', 'Padmaja']
